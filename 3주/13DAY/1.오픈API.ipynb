# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 구로동 11530 /22년 10월

# %%
req = requests.get('http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=0kYXnKBN3P1BPz%2BPbMj53%2BXf9Lasd9mZvYohzWDq%2B10Tagyqazw0pf62r0VMYgKLZZednlK4k5uPA6V49OvEcw%3D%3D&LAWD_CD=11530&DEAL_YMD=202210')

# %%
soup = BeautifulSoup(req.text, 'xml')

# %%
#건축년도 / 년월일(20221001) / 법정동 / 보증금액 
#아파트 /월세금액 /전용면적 / 층

# %%
#list = ['건축년도' ,'년월일' , '법정동', '보증금액' ,'아파트' ,'월세금액','전용면적', '층']

# %%
gun = soup.select('건축년도')

# %%
gun
# Out:
# [<건축년도>2000</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>1996</건축년도>,
#  <건축년도>2004</건축년도>,
#  <건축년도>2011</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1987</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2018</건축년도>,
#  <건축년도>1994</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1989</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>2006</건축년도>,
#  <건축년도>2000</건축년도>,
#  <건축년도>2015</건축년도>,
#  <건축년도>2015</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2011</건축년도>,
#  <건축년도>1987</건축년도>,
#  <건축년도>1989</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1994</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2004</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2003</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2000</건축년도>,
#  <건축년도>2006</건축년도>,
#  <건축년도>1997</건축년도>,
#  <건축년도>1993</건축년도>,
#  <건축년도>2021</건축년도>,
#  <건축년도>2000</건축년도>,
#  <건축년도>1999</건축년도>,
#  <건축년도>2001</건축년도>,
#  <건축년도>2004</건축년도>,
# ...

# %%
month = soup.select('월')

# %%
day = soup.select('일')

# %%
bub = soup.select('법정동')

# %%
bub
# Out:
# [<법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
#  <법정동> 신도림동</법정동>,
# ...

# %%
bojug = soup.select('보증금액')

# %%
bojug
# Out:
# [<보증금액>    31,000</보증금액>,
#  <보증금액>    25,000</보증금액>,
#  <보증금액>    48,000</보증금액>,
#  <보증금액>    60,000</보증금액>,
#  <보증금액>   120,000</보증금액>,
#  <보증금액>    10,000</보증금액>,
#  <보증금액>    40,000</보증금액>,
#  <보증금액>    35,000</보증금액>,
#  <보증금액>    30,000</보증금액>,
#  <보증금액>     1,000</보증금액>,
#  <보증금액>    20,000</보증금액>,
#  <보증금액>    70,000</보증금액>,
#  <보증금액>    39,500</보증금액>,
#  <보증금액>    26,460</보증금액>,
#  <보증금액>    84,000</보증금액>,
#  <보증금액>    57,750</보증금액>,
#  <보증금액>    35,000</보증금액>,
#  <보증금액>    94,500</보증금액>,
#  <보증금액>    31,600</보증금액>,
#  <보증금액>    32,000</보증금액>,
#  <보증금액>     5,000</보증금액>,
#  <보증금액>    40,200</보증금액>,
#  <보증금액>   118,000</보증금액>,
#  <보증금액>    37,000</보증금액>,
#  <보증금액>    15,000</보증금액>,
#  <보증금액>    39,375</보증금액>,
#  <보증금액>    41,500</보증금액>,
#  <보증금액>    52,000</보증금액>,
#  <보증금액>    86,000</보증금액>,
#  <보증금액>    46,200</보증금액>,
#  <보증금액>    47,000</보증금액>,
#  <보증금액>    64,050</보증금액>,
#  <보증금액>    20,000</보증금액>,
#  <보증금액>    78,750</보증금액>,
#  <보증금액>    50,000</보증금액>,
# ...

# %%
apart = soup.select('아파트')

# %%
apart
# Out:
# [<아파트>동아2</아파트>,
#  <아파트>대림3</아파트>,
#  <아파트>우성2</아파트>,
#  <아파트>대림e-편한세상7</아파트>,
#  <아파트>디큐브시티</아파트>,
#  <아파트>현대홈타운아파트</아파트>,
#  <아파트>미성</아파트>,
#  <아파트>동아1</아파트>,
#  <아파트>동아1</아파트>,
#  <아파트>신도림 아르디에</아파트>,
#  <아파트>우성5</아파트>,
#  <아파트>대림2</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>미성</아파트>,
#  <아파트>대림e-편한세상4</아파트>,
#  <아파트>대림e-편한세상6</아파트>,
#  <아파트>SKVIEW</아파트>,
#  <아파트>동아3</아파트>,
#  <아파트>신도림아이파크</아파트>,
#  <아파트>신도림아이파크</아파트>,
#  <아파트>대림2</아파트>,
#  <아파트>대림2</아파트>,
#  <아파트>디큐브시티</아파트>,
#  <아파트>미성</아파트>,
#  <아파트>미성</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>우성5</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>대림e-편한세상4</아파트>,
#  <아파트>동아1</아파트>,
#  <아파트>대림2</아파트>,
#  <아파트>대림e-편한세상7</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>대림e-편한세상4</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>동아2</아파트>,
#  <아파트>SKVIEW</아파트>,
#  <아파트>신성은하수</아파트>,
#  <아파트>우성3</아파트>,
#  <아파트>상림빌딩</아파트>,
#  <아파트>동아2</아파트>,
#  <아파트>동아1</아파트>,
#  <아파트>대림2</아파트>,
#  <아파트>대림e-편한세상7</아파트>,
#  <아파트>동아3</아파트>,
#  <아파트>대림2</아파트>,
#  <아파트>대림1</아파트>,
#  <아파트>동아2</아파트>,
# ...

# %%
monthpay = soup.select('월세금액')

# %%
monthpay
# Out:
# [<월세금액>         0</월세금액>,
#  <월세금액>       120</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>        55</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>        60</월세금액>,
#  <월세금액>        90</월세금액>,
#  <월세금액>        73</월세금액>,
#  <월세금액>        70</월세금액>,
#  <월세금액>        45</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>       100</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>        40</월세금액>,
#  <월세금액>        41</월세금액>,
#  <월세금액>       165</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         7</월세금액>,
#  <월세금액>        20</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>       119</월세금액>,
#  <월세금액>         0</월세금액>,
#  <월세금액>         0</월세금액>,
# ...

# %%
jun = soup.select('전용면적')

# %%
jun
# Out:
# [<전용면적>59.595</전용면적>,
#  <전용면적>84.51</전용면적>,
#  <전용면적>84.82</전용면적>,
#  <전용면적>84.928</전용면적>,
#  <전용면적>128.41</전용면적>,
#  <전용면적>59.73</전용면적>,
#  <전용면적>83.67</전용면적>,
#  <전용면적>59.978</전용면적>,
#  <전용면적>84.908</전용면적>,
#  <전용면적>21.38</전용면적>,
#  <전용면적>59.91</전용면적>,
#  <전용면적>134.99</전용면적>,
#  <전용면적>59.88</전용면적>,
#  <전용면적>52.45</전용면적>,
#  <전용면적>117.74</전용면적>,
#  <전용면적>84.816</전용면적>,
#  <전용면적>84.96</전용면적>,
#  <전용면적>138.412</전용면적>,
#  <전용면적>57.2934</전용면적>,
#  <전용면적>56.2646</전용면적>,
#  <전용면적>84.95</전용면적>,
#  <전용면적>59.88</전용면적>,
#  <전용면적>125.36</전용면적>,
#  <전용면적>66.03</전용면적>,
#  <전용면적>37.91</전용면적>,
#  <전용면적>59.88</전용면적>,
#  <전용면적>59.91</전용면적>,
#  <전용면적>59.9</전용면적>,
#  <전용면적>152.07</전용면적>,
#  <전용면적>59.978</전용면적>,
#  <전용면적>59.93</전용면적>,
#  <전용면적>84.928</전용면적>,
#  <전용면적>134.99</전용면적>,
#  <전용면적>84.78</전용면적>,
#  <전용면적>59.88</전용면적>,
#  <전용면적>59.88</전용면적>,
#  <전용면적>84.908</전용면적>,
#  <전용면적>84.98</전용면적>,
#  <전용면적>84.42</전용면적>,
#  <전용면적>84.75</전용면적>,
#  <전용면적>17.9146</전용면적>,
#  <전용면적>59.595</전용면적>,
# ...

# %%
floor = soup.select('층')

# %%
floor
# Out:
# [<층>4</층>,
#  <층>13</층>,
#  <층>4</층>,
#  <층>3</층>,
#  <층>34</층>,
#  <층>7</층>,
#  <층>10</층>,
#  <층>25</층>,
#  <층>18</층>,
#  <층>4</층>,
#  <층>8</층>,
#  <층>3</층>,
#  <층>23</층>,
#  <층>4</층>,
#  <층>11</층>,
#  <층>13</층>,
#  <층>2</층>,
#  <층>2</층>,
#  <층>4</층>,
#  <층>12</층>,
#  <층>11</층>,
#  <층>6</층>,
#  <층>16</층>,
#  <층>6</층>,
#  <층>4</층>,
#  <층>21</층>,
#  <층>6</층>,
#  <층>24</층>,
#  <층>14</층>,
#  <층>15</층>,
#  <층>14</층>,
#  <층>12</층>,
#  <층>4</층>,
#  <층>5</층>,
#  <층>5</층>,
#  <층>26</층>,
#  <층>5</층>,
#  <층>18</층>,
#  <층>7</층>,
#  <층>2</층>,
#  <층>4</층>,
#  <층>9</층>,
#  <층>5</층>,
#  <층>17</층>,
#  <층>8</층>,
#  <층>9</층>,
#  <층>20</층>,
#  <층>21</층>,
#  <층>19</층>,
#  <층>7</층>,
#  <층>1</층>,
#  <층>15</층>,
#  <층>7</층>,
#  <층>24</층>,
#  <층>10</층>,
#  <층>3</층>,
#  <층>22</층>,
#  <층>2</층>,
#  <층>12</층>,
#  <층>1</층>,
#  <층>2</층>,
#  <층>4</층>,
#  <층>19</층>,
#  <층>31</층>,
#  <층>5</층>,
#  <층>18</층>,
#  <층>4</층>,
#  <층>26</층>,
#  <층>4</층>,
#  <층>1</층>,
#  <층>4</층>,
#  <층>5</층>,
#  <층>19</층>,
#  <층>9</층>,
# ...

# %%
data = []
for i in range(len(gun)) :
    temp = []
    temp.append(gun[i].text)
    temp.append(bub[i].text)
    temp.append(bojug[i].text)
    temp.append(apart[i].text)
    temp.append(monthpay[i].text)
    temp.append(jun[i].text)
    temp.append(floor[i].text)
    temp.append(month[i].text)
    temp.append(day[i].text)
    data.append(temp)

# %%
df = pd.DataFrame(data, columns = ['건축년도'  , '법정동', '보증금액' ,'아파트' ,'월세금액','전용면적', '층','월','일'])

# %%
df
# Out:
#      건축년도    법정동        보증금액         아파트        월세금액     전용면적   층   월   일
# 0    2000   신도림동      31,000         동아2           0   59.595   4  10   2
# 1    2001   신도림동      25,000         대림3         120    84.51  13  10   3
# 2    1996   신도림동      48,000         우성2           0    84.82   4  10   4
# 3    2004   신도림동      60,000   대림e-편한세상7           0   84.928   3  10   4
# 4    2011   신도림동     120,000       디큐브시티           0   128.41  34  10   4
# ..    ...    ...         ...         ...         ...      ...  ..  ..  ..
# 447  2017    천왕동       6,452  천왕이펜하우스7단지           3    29.96   3  10  25
# 448  2011    천왕동       9,635  천왕이펜하우스4단지           0    49.58   9  10  26
# 449  2014    천왕동      57,000   천왕연지타운2단지           0    84.98   4  10  31
# 450  2019     항동      50,000   한양수자인에듀힐즈           0  84.9544   3  10   8
# 451  2019     항동      27,500     하버라인4단지           0    59.86  10  10  29
#
# [452 rows x 9 columns]

# %%
df['년월일(20221001)'] = df['건축년도'] +df['월'].str.zfill(2) + df['일'].str.zfill(2)

# %%
df
# Out:
#      건축년도    법정동        보증금액         아파트        월세금액     전용면적   층   월   일  \
# 0    2000   신도림동      31,000         동아2           0   59.595   4  10   2
# 1    2001   신도림동      25,000         대림3         120    84.51  13  10   3
# 2    1996   신도림동      48,000         우성2           0    84.82   4  10   4
# 3    2004   신도림동      60,000   대림e-편한세상7           0   84.928   3  10   4
# 4    2011   신도림동     120,000       디큐브시티           0   128.41  34  10   4
# ..    ...    ...         ...         ...         ...      ...  ..  ..  ..
# 447  2017    천왕동       6,452  천왕이펜하우스7단지           3    29.96   3  10  25
# 448  2011    천왕동       9,635  천왕이펜하우스4단지           0    49.58   9  10  26
# 449  2014    천왕동      57,000   천왕연지타운2단지           0    84.98   4  10  31
# 450  2019     항동      50,000   한양수자인에듀힐즈           0  84.9544   3  10   8
# 451  2019     항동      27,500     하버라인4단지           0    59.86  10  10  29
#
#     년월일(20221001)
# 0        20001002
# 1        20011003
# 2        19961004
# ...

# %%
#df.drop(['월'],axis=1, inplace=True)

# %%
#df.drop(['일'],axis=1, inplace=True)

# %%
df.drop(['월','일'],axis=1, inplace=True)

# %%
df
# Out:
#      건축년도    법정동        보증금액         아파트        월세금액     전용면적   층  \
# 0    2000   신도림동      31,000         동아2           0   59.595   4
# 1    2001   신도림동      25,000         대림3         120    84.51  13
# 2    1996   신도림동      48,000         우성2           0    84.82   4
# 3    2004   신도림동      60,000   대림e-편한세상7           0   84.928   3
# 4    2011   신도림동     120,000       디큐브시티           0   128.41  34
# ..    ...    ...         ...         ...         ...      ...  ..
# 447  2017    천왕동       6,452  천왕이펜하우스7단지           3    29.96   3
# 448  2011    천왕동       9,635  천왕이펜하우스4단지           0    49.58   9
# 449  2014    천왕동      57,000   천왕연지타운2단지           0    84.98   4
# 450  2019     항동      50,000   한양수자인에듀힐즈           0  84.9544   3
# 451  2019     항동      27,500     하버라인4단지           0    59.86  10
#
#     년월일(20221001)
# 0        20001002
# 1        20011003
# 2        19961004
# 3        20041004
# 4        20111004
# ..            ...
# 447      20171025
# ...

# %% [markdown]
# ----------

# %%
#선생님 풀이

# %%
col_names = []
for item in soup.items()[0] :
    col_names.append(item.name)

# %%
soup.items
# Out:
# <items><item><갱신요구권사용> </갱신요구권사용><건축년도>2000</건축년도><계약구분> </계약구분><계약기간> </계약기간><년>2022</년><법정동> 신도림동</법정동><보증금액>    31,000</보증금액><아파트>동아2</아파트><월>10</월><월세금액>         0</월세금액><일>2</일><전용면적>59.595</전용면적><종전계약보증금> </종전계약보증금><종전계약월세> </종전계약월세><지번>644</지번><지역코드>11530</지역코드><층>4</층></item><item><갱신요구권사용> </갱신요구권사용><건축년도>2001</건축년도><계약구분> </계약구분><계약기간> </계약기간><년>2022</년><법정동> 신도림동</법정동><보증금액>    25,000</보증금액><아파트>대림3</아파트><월>10</월><월세금액>       120</월세금액><일>3</일><전용면적>84.51</전용면적><종전계약보증금> </종전계약보증금><종전계약월세> </종전계약월세><지번>691</지번><지역코드>11530</지역코드><층>13</층></item><item><갱신요구권사용> </갱신요구권사용><건축년도>1996</건축년도><계약구분> </계약구분><계약기간> </계약기간><년>2022</년><법정동> 신도림동</법정동><보증금액>    48,000</보증금액><아파트>우성2</아파트><월>10</월><월세금액>         0</월세금액><일>4</일><전용면적>84.82</전용면적><종전계약보증금> </종전계약보증금><종전계약월세> </종전계약월세><지번>639</지번><지역코드>11530</지역코드><층>4</층></item><item><갱신요구권사용> </갱신요구권사용><건축년도>2004</건축년도><계약구분> </계약구분><계약기간> </계약기간><년>2022</년><법정동> 신도림동</법정동><보증금액>    60,000</보증금액><아파트>대림e-편한세상7</아파트><월>10</월><월세금액>     
# ...

# %%
data = []
for item in soup.items :
    temp = []
    for t in item :
        temp.append(t.text.strip())
    data.append(temp)

# %%
data
# Out:
# [['',
#   '2000',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '31,000',
#   '동아2',
#   '10',
#   '0',
#   '2',
#   '59.595',
#   '',
#   '',
#   '644',
#   '11530',
#   '4'],
#  ['',
#   '2001',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '25,000',
#   '대림3',
#   '10',
#   '120',
#   '3',
#   '84.51',
#   '',
#   '',
#   '691',
#   '11530',
#   '13'],
#  ['',
#   '1996',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '48,000',
#   '우성2',
#   '10',
#   '0',
#   '4',
#   '84.82',
#   '',
#   '',
#   '639',
#   '11530',
#   '4'],
#  ['',
#   '2004',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '60,000',
#   '대림e-편한세상7',
#   '10',
#   '0',
#   '4',
#   '84.928',
#   '',
#   '',
#   '649',
#   '11530',
#   '3'],
#  ['',
#   '2011',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '120,000',
#   '디큐브시티',
#   '10',
#   '0',
#   '4',
#   '128.41',
#   '',
#   '',
#   '692',
#   '11530',
#   '34'],
#  ['',
#   '1999',
#   '',
#   '',
#   '2022',
#   '신도림동',
#   '10,000',
#   '현대홈타운아파트',
#   '10',
# ...

# %%
df = pd.DataFrame(data, columns = col_names)

# %%
df
# Out:
#     갱신요구권사용  건축년도 계약구분 계약기간     년   법정동     보증금액         아파트   월 월세금액   일  \
# 0            2000            2022  신도림동   31,000         동아2  10    0   2
# 1            2001            2022  신도림동   25,000         대림3  10  120   3
# 2            1996            2022  신도림동   48,000         우성2  10    0   4
# 3            2004            2022  신도림동   60,000   대림e-편한세상7  10    0   4
# 4            2011            2022  신도림동  120,000       디큐브시티  10    0   4
# ..      ...   ...  ...  ...   ...   ...      ...         ...  ..  ...  ..
# 447          2017            2022   천왕동    6,452  천왕이펜하우스7단지  10    3  25
# 448          2011            2022   천왕동    9,635  천왕이펜하우스4단지  10    0  26
# 449          2014            2022   천왕동   57,000   천왕연지타운2단지  10    0  31
# 450          2019            2022    항동   50,000   한양수자인에듀힐즈  10    0   8
# 451          2019            2022    항동   27,500     하버라인4단지  10    0  29
#
#         전용면적 종전계약보증금 종전계약월세     지번   지역코드   층
# ...

# %%
import numpy as np

# %%
df = df.replace('',np.nan)

# %%
df = df.dropna(axis =1)

# %%
# .zfill() : 문자열에서 쓰는것 , ()안에 수만큼 자리르 0으로 채움
df['계약일'] = df['년']+df['월'].str.zfill(2)+df['일'].str.zfill(2)

# %%
df.drop(['년','월','일'],axis=1,inplace=True)

# %%
df
# Out:
#      건축년도   법정동     보증금액         아파트 월세금액     전용면적     지번   지역코드   층       계약일
# 0    2000  신도림동   31,000         동아2    0   59.595    644  11530   4  20221002
# 1    2001  신도림동   25,000         대림3  120    84.51    691  11530  13  20221003
# 2    1996  신도림동   48,000         우성2    0    84.82    639  11530   4  20221004
# 3    2004  신도림동   60,000   대림e-편한세상7    0   84.928    649  11530   3  20221004
# 4    2011  신도림동  120,000       디큐브시티    0   128.41    692  11530  34  20221004
# ..    ...   ...      ...         ...  ...      ...    ...    ...  ..       ...
# 447  2017   천왕동    6,452  천왕이펜하우스7단지    3    29.96    274  11530   3  20221025
# 448  2011   천왕동    9,635  천왕이펜하우스4단지    0    49.58    273  11530   9  20221026
# 449  2014   천왕동   57,000   천왕연지타운2단지    0    84.98    281  11530   4  20221031
# 450  2019    항동   50,000   한양수자인에듀힐즈    0  84.9544  가-241  11530   3  20221008
# 451  2019    항동   27,500     하버라인4단지    0    59.86  가-238  11530  10  20221029
#
# [452 rows x 10 columns]

# %% [markdown]
# -

# %%
soup.items()[0]
# Out:
# <item><갱신요구권사용> </갱신요구권사용><건축년도>2000</건축년도><계약구분> </계약구분><계약기간> </계약기간><년>2022</년><법정동> 신도림동</법정동><보증금액>    31,000</보증금액><아파트>동아2</아파트><월>10</월><월세금액>         0</월세금액><일>2</일><전용면적>59.595</전용면적><종전계약보증금> </종전계약보증금><종전계약월세> </종전계약월세><지번>644</지번><지역코드>11530</지역코드><층>4</층></item>

# %%
col_names =[]
for item in soup.items()[0] :
    col_names.append(item.name)

# %%
col_names
# Out:
# ['갱신요구권사용',
#  '건축년도',
#  '계약구분',
#  '계약기간',
#  '년',
#  '법정동',
#  '보증금액',
#  '아파트',
#  '월',
#  '월세금액',
#  '일',
#  '전용면적',
#  '종전계약보증금',
#  '종전계약월세',
#  '지번',
#  '지역코드',
#  '층']

# %% [markdown]
# -

# %%
#구로동(11530) /22년 6월 ~10월까지

# %%
url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=0kYXnKBN3P1BPz%2BPbMj53%2BXf9Lasd9mZvYohzWDq%2B10Tagyqazw0pf62r0VMYgKLZZednlK4k5uPA6V49OvEcw%3D%3D&LAWD_CD=11530&DEAL_YMD=202210'
req = requests.get(url)

# %%
url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent?serviceKey=0kYXnKBN3P1BPz%2BPbMj53%2BXf9Lasd9mZvYohzWDq%2B10Tagyqazw0pf62r0VMYgKLZZednlK4k5uPA6V49OvEcw%3D%3D&LAWD_CD=11530&DEAL_YMD=' + '202206'

# %% [markdown]
# --

# %%
#tqdm : for문 얼마나 진행되었는지 확인 가능 
c

# %%
col_names = []
data = []

for m in tqdm(range(6,11)) :
    url ='http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptRent'
    serviceKey ='0kYXnKBN3P1BPz%2BPbMj53%2BXf9Lasd9mZvYohzWDq%2B10Tagyqazw0pf62r0VMYgKLZZednlK4k5uPA6V49OvEcw%3D%3D'
    lawd_cd = '11530' #지역
    deal_ymd = '2022' + str(m).zfill(2) # 계약일
    
    api_url = url + '?' + 'serviceKey=' + serviceKey + '&LAWD_CD=' + lawd_cd + '&DEAL_YMD=' + deal_ymd  

    
    req = requests.get(api_url)
    soup = BeautifulSoup(req.text, 'xml')
   

    if not col_names :
        for item in soup.items()[0] :
            col_names.append(item.name)
   
    for item in soup.items :
        temp = []
        for t in item :
            temp.append(t.text.strip())
        data.append(temp)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:04<00:00,  1.08it/s]

# %%
df = pd.DataFrame(data,columns=col_names)

# %%
df.shape
# Out:
# (4135, 17)

# %%
df = df.replace('',np.nan)

# %%
df.isnull().sum()
# Out:
# 갱신요구권사용    3627
# 건축년도          0
# 계약구분       1641
# 계약기간       1812
# 년             0
# 법정동           0
# 보증금액          0
# 아파트           0
# 월             0
# 월세금액          0
# 일             0
# 전용면적          0
# 종전계약보증금    1641
# 종전계약월세     1641
# 지번            0
# 지역코드          0
# 층             0
# dtype: int64

# %%
df['계약구분'].value_counts()
# Out:
# 갱신    1433
# 신규    1061
# Name: 계약구분, dtype: int64

# %%
df
# Out:
#      갱신요구권사용  건축년도 계약구분         계약기간     년   법정동     보증금액         아파트   월  \
# 0        NaN  2011   신규  22.08~24.08  2022  신도림동   58,800       디큐브시티   6
# 1         사용  2000   갱신  22.10~24.10  2022  신도림동   41,400         동아2   6
# 2        NaN  2003   신규  22.08~24.08  2022  신도림동  130,000   대림e-편한세상4   6
# 3        NaN  2000  NaN          NaN  2022  신도림동   42,900         동아3   6
# 4        NaN  1999   신규  22.08~24.08  2022  신도림동   75,000         동아1   6
# ...      ...   ...  ...          ...   ...   ...      ...         ...  ..
# 4130     NaN  2017  NaN          NaN  2022   천왕동    6,452  천왕이펜하우스7단지  10
# 4131     NaN  2011  NaN          NaN  2022   천왕동    9,635  천왕이펜하우스4단지  10
# 4132     NaN  2014  NaN          NaN  2022   천왕동   57,000   천왕연지타운2단지  10
# 4133     NaN  2019  NaN          NaN  2022    항동   50,000   한양수자인에듀힐즈  10
# 4134     NaN  2019  NaN          NaN  2022    항동   27,500     하버라인4단지  10
#
#      월세금액   일     전용면적 종전계약보증금 종전계약월세     지번   지역코드   층
# ...

# %%
df_decuve = df[(df['아파트'] == '디큐브시티')& (df['월세금액'] == '0')]

# %%
df_decuve['전용면적'].unique()
# Out:
# array(['59.16', '84.96', '128.41', '59.84', '59.86', '105.45', '125.36'],
#       dtype=object)

# %%
df_decuve['전용면적'].value_counts()
# Out:
# 84.96     4
# 59.86     4
# 128.41    3
# 105.45    3
# 125.36    3
# 59.16     1
# 59.84     1
# Name: 전용면적, dtype: int64

# %% [markdown]
# --

# %%
df['아파트'].value_counts()
# Out:
# 센트레빌레우스1단지    1050
# 천왕이펜하우스7단지     202
# 고척아이파크          98
# 현대              91
# 한마을             84
#               ...
# 우성에비뉴            1
# (794-46)         1
# (743-10)         1
# 대성               1
# 리치안풍산            1
# Name: 아파트, Length: 327, dtype: int64

# %%
#월별 월세 변화량(전용면적 고려)
#월세의 경우 보증금액 변화도 고려

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_sen = df[df['아파트'] == '센트레빌레우스1단지']

# %%
df_sen.columns
# Out:
# Index(['갱신요구권사용', '건축년도', '계약구분', '계약기간', '년', '법정동', '보증금액', '아파트', '월',
#        '월세금액', '일', '전용면적', '종전계약보증금', '종전계약월세', '지번', '지역코드', '층'],
#       dtype='object')

# %%
df_sen['월세금액'] = df_sen['월세금액'].astype(int)

# %%
df_sen['월세금액'].describe()
# Out:
# count    1050.000000
# mean       46.046667
# std        14.885157
# min        36.000000
# 25%        40.000000
# 50%        43.000000
# 75%        45.000000
# max       432.000000
# Name: 월세금액, dtype: float64

# %%
df_sen[(df_sen['전용면적'] == '84.9716') &  (df_sen['층'] == '6')][['계약구분','보증금액','월','일','월세금액']].sort_values('월')
# Out:
#      계약구분    보증금액  월   일  월세금액
# 523    갱신  27,891  6   3    43
# 757   NaN  17,561  6  16    71
# 762   NaN  17,561  6  16    71
# 768    갱신  17,561  6  16    71
# 1648  NaN  27,891  7   1   432
# 1668   갱신  27,891  7   1    43
# 2125   갱신  27,891  7  26    43
# 2143  NaN  27,891  7  27    43
# 2160  NaN  27,891  7  27    43

# %%
df_sen.loc[1648,'월세금액'] = 43

# %%
df_sen['월세금액'].max()
# Out:
# 73

# %%
df_sen.groupby(['월','전용면적'])['월세금액'].median().reset_index().sort_values('월세금액' , ascending= False)
# Out:
#      월     전용면적  월세금액
# 12   7  84.9407  45.0
# 9    6  84.9716  45.0
# 23   9  84.9625  45.0
# 22   9  84.9407  45.0
# 19   8  84.9716  45.0
# 18   8  84.9625  45.0
# 17   8  84.9407  45.0
# 14   7  84.9716  45.0
# 13   7  84.9625  45.0
# 24   9  84.9716  45.0
# 8    6  84.9625  45.0
# 7    6  84.9407  45.0
# 4   10  84.9716  45.0
# 3   10  84.9625  45.0
# 2   10  84.9407  45.0
# 1   10  74.9361  43.0
# 16   8  74.9361  43.0
# 21   9  74.9361  43.0
# 0   10  74.9145  43.0
# 10   7  74.9145  40.0
# 11   7  74.9361  40.0
# 15   8  74.9145  40.0
# 6    6  74.9361  40.0
# 5    6  74.9145  40.0
# 20   9  74.9145  40.0

# %%
df_sen[df_sen['월세금액'] ==  df_sen['월세금액'].max()]
# Out:
#      갱신요구권사용  건축년도 계약구분 계약기간     년  법정동    보증금액         아파트  월  월세금액  일  \
# 1648     NaN  2020  NaN  NaN  2022  개봉동  27,891  센트레빌레우스1단지  7   432  1
#
#          전용면적 종전계약보증금 종전계약월세   지번   지역코드  층
# 1648  84.9716     NaN    NaN  497  11530  6

# %%
df_sen['보증금액'] = df_sen['보증금액'].str.replace(',','')

# %%
df_sen['보증금액'] = df_sen['보증금액'].astype(int)

# %%
df_sen_group = df_sen.groupby(['월', '전용면적'])['보증금액','월세금액'].mean().reset_index()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
sns.pointplot(x='월', y= '보증금액', hue='전용면적' ,
             data= df_sen_group );

# %%
df_sen['보증금액'].describe()
# Out:
# count     1050.000000
# mean     25200.735238
# std       3645.703011
# min       2891.000000
# 25%      25825.000000
# 50%      25825.000000
# 75%      27891.000000
# max      27891.000000
# Name: 보증금액, dtype: float64

# %%
df_sen_group.plot(x = '월', y = '보증금액');
